# %%
import pandas as pd
import numpy as np

df = pd.read_csv("fixed_dataset_for_sql.csv")
df = df.drop_duplicates()
# Out:
#    column1                track_id                 artists  \
# 0        1  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1        2  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2        3  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3        4  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4        5  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.drop(['column1', 'album_name', 'popularity',
         'duration_ms', 'explicit', 'danceability',
         'key', 'loudness', 'mode', 'speechiness', 'acousticness',
         'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'], axis='columns', inplace=True)
# Out:
#                       track_id           artists           track_name  energy  \
# 113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby  Sleep My Little Boy   0.235
# 113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby     Water Into Light   0.117
# 113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora       Miss Perfumado   0.329
# 113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith              Friends   0.506
# 113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora            Barbincor   0.487
#
#         track_genre
# 113995  world-music
# 113996  world-music
# 113997  world-music
# 113998  world-music
# 113999  world-music

# %%
columns_to_drop = [f"artist38"]
df.drop(columns=columns_to_drop, inplace=True)
# Out:
#                  track_id                  track_name  energy track_genre  \
# 0  5SuOikwiRyPMVoIQDJUgSV                      Comedy  0.4610    acoustic
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ghost - Acoustic  0.1660    acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b              To Begin Again  0.3590    acoustic
# 3  6lfxq3CG4xtTiEg7opyCyx  Can't Help Falling In Love  0.0596    acoustic
# 4  5vjLSffimiIP26QG5WcN2K                     Hold On  0.4430    acoustic
# 5  01MVOl9KtVTNfFiBU9I7dc        Days I Will Remember  0.4810    acoustic
# 6  6Vc5wAMmXdKIAM7WUoEb7N               Say Something  0.1470    acoustic
# 7  1EzrEOXmMH3G43AXT1y7pA                   I'm Yours  0.4440    acoustic
# 8  0IktbUcnAGrvD03AWnz3Q8                       Lucky  0.4140    acoustic
# 9  7k9GuJYLp2AzqokyEdwEw2                      Hunger  0.6320    acoustic
#
#              artist1             artist2 artist3 artist4
# 0        Gen Hoshino                None    None    None
# ...

# %%
df['track_name'] = df['track_name'].str.replace(',', '.', regex=False)

# %%
df.to_csv("clean2_data.csv", index=False)
